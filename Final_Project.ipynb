# %% [markdown]
# <a href="https://colab.research.google.com/github/plumwiserim/Python-Programming-2/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 크롤링(crawling)이란?
# 1. 웹상에 존재하는 컨텐츠를 수집하는 작업
# 2. HTML 페이지를 가져와서, HTML/CSS등을 파싱하고, 필요한 데이터만 추출하는 기법

# %% [markdown]
# ## 파싱(Parsing)이란?
# 언어학에서 파싱은 구문분석으로 문장을 이루고 있는 구성 성분으로 분해하고 그들 사이의 위계관계를 분석하여 문장의 구조를 결정하는 것
#
# 컴퓨터 과학에서 파싱은 일련의 문자열을 의미있는 어휘 분석 단위로 분해하고 이들로 이루어진 파스 트리(parse tree)를 만드는 과정
#
# 포함하는 태그가 부모가 되고 포함된 태그가 자식이 되어 트리를 구성함
#
# 예를 들어 html 태그아래에 head와 body 태그가 존재하고 다시 head와 body 태그 아래에 하위 태그가 존재함
#
#
# ![파싱](http://www.aistudy.co.kr/linguistics/natural/images/parsing.gif)

# %% [markdown]
# <p style="text-align: center;"><br/></p><p style="text-align: center;"><br/></p><p style="text-align: center;"><br/></p><p style="text-align: center;"><br/></p><p style="text-align: center;"><b><span style="font-size: 11pt;">html 기본 태그 ' &lt;head&gt; 안에 들어갈 태그 '</span></b></p><p style="text-align: center;"><b><span style="font-size: 11pt;"><br/></span></b></p><p></p><p style="text-align: center;"><br/></p><p style="text-align: left;"><b><span style="font-size: 10pt;">1. </span><span style="font-size: 10pt;">&lt;meta</span><span style="font-size: 10pt;">&gt; 태그</span></b></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 10pt;">&lt;meta&gt; 태그는 본 문서의 키워드 혹은 제목, 요약을 나타내는 태그로서 활용되게 됩니다. </span></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 11pt;"><b><span style="font-size: 10pt;">2. &lt;title&gt; 태그</span></b></span></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 10pt;">Ex) &lt;title&gt; NAVER &lt;</span><span style="font-size: 10pt;">/title&gt;</span></p><p style="text-align: left;"><span style="font-size: 10pt;">&lt;title&gt; 태그는 문서의 제목을 나타내는 태그로서 활용됩니다. </span></p><p style="text-align: left; clear: none; float: none;"><span class="imageblock" style="display:inline-block;width:352px;;height:auto;max-width:100%"><img filemime="image/jpeg" filename="스크린샷 2016-02-01 오후 10.17.13.png" height="54" src="https://t1.daumcdn.net/cfile/tistory/274B6B4B56AF5AF025" style="max-width:100%;height:auto" width="352"/></span></p><p style="text-align: left;"><span style="font-size: 10pt;">이와 같이 웹페이지를 띄우게 되면  naver 라는 타이틀이 뜨게 되는 부분을 말합니다.</span></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 11pt;"><b><span style="font-size: 10pt;">3. &lt;link&gt; 태그</span></b></span></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 10pt;">Ex) &lt;link </span><span style="line-height: 1.5;"><span style="font-size: 10pt;">href="</span><span style="font-size: 10pt;">/style.css"</span></span><span style="line-height: 1.5; font-size: 10pt;"> </span><span style="line-height: 1.5; font-size: 10pt;">rel="stylesheet" </span><span style="line-height: 1.5; font-size: 10pt;">type="text/css" </span><span style="line-height: 1.5; font-size: 10pt;">/&gt;</span></p><p style="text-align: left;"><span style="font-size: 10pt;">&lt;link&gt; 태그는 </span><span style="font-family: NanumGothic, 'Nanum Gothic', 'Malgun Gothic', dotum, Arial, Helvetica, sans-serif; font-size: 10pt; line-height: 28.8px; text-indent: 8px;">주로 css 파일을 연결할 때 사용하는 태그입니다. 여기서 css란 웹페이지의 스타일이 미리 저장되어있어서 유지, 보수가 간편한 스타일시트입니다. link 요소의 속성들을 살펴보면, </span><span style="font-family: NanumGothic, 'Nanum Gothic', 'Malgun Gothic', dotum, Arial, Helvetica, sans-serif; font-size: 16px; line-height: 28.8px; text-indent: 8px;"><span style="font-size: 10pt;">'href'는 해당 css파일의 주소를 적게 됩니다.</span></span></p>

# %% [markdown]
# <p style="text-align: center;"><b style="text-align: center;"><span style="font-size:11pt;">html 기본 태그 ' &lt;body</span><span style="font-size: 11pt;">&gt; 안에 들어갈 태그 '</span></b></p><p style="text-align: center;"><b style="text-align: center;"><span style="font-size: 11pt;"><br/></span></b></p><p></p><p style="text-align: center;"><b style="text-align: center;"><span style="font-size: 11pt;"><br/></span></b></p><p style="text-align: left;"><b style="text-align: center;"><span style="font-size:10pt;">1. 제목태그 &lt;h1&gt;,&lt;h2&gt;,&lt;h3&gt;,</span></b><b style="line-height: 1.5;"><span style="font-size: 10pt;">&lt;h4&gt;,</span></b><b style="line-height: 1.5;"><span style="font-size: 10pt;">&lt;h5&gt;,</span></b><b style="line-height: 1.5;"><span style="font-size:10pt;">&lt;h6&gt;</span></b></p><p style="text-align: left;"><b style="line-height: 1.5;"></b></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">제목태그는 말 그대로 문서의 본문의 헤드라인 요소입니다. 이 헤드라인 요소는 문서에 있어 중요한 요소로서 웹 페이지의 대한 개요를 헤드라인 요소로서 판단하게 되는 기준입니다. 예를 들어 아래와 같이 문서의 구조를 결정하게 됩니다. </span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">&lt;h1&gt; HTML 이란? </span><span style="font-size: 10pt;">&lt;/h1&gt;</span></span></p><p style="text-align: left; margin-left: 2em;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">&lt;h2&gt; HTML 의 역사 </span><span style="font-size: 10pt;">&lt;/h2&gt;</span></span></p><p style="text-align: left; margin-left: 4em;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">&lt;h3&gt; 팀 버너스리에 대해 </span><span style="font-size: 10pt;">&lt;/h3&gt;</span></span></p><p style="text-align: left; margin-left: 2em;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">&lt;h2&gt; HTML 의 태그 </span><span style="font-size: 10pt;">&lt;/h2&gt;</span></span></p><p style="text-align: left; margin-left: 4em;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">&lt;</span><span style="font-size: 10pt;">h3&gt; &lt;head&gt;안에 들어가는 태그 </span><span style="font-size: 10pt;">&lt;/h3&gt;</span></span></p><p style="text-align: left; margin-left: 4em;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">&lt;h3&gt; &lt;body&gt; </span><span style="font-size: 10pt;">&lt;/h3&gt;</span></span></p><p style="text-align: left; margin-left: 4em;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">이는 ' HTML 이란? ' 의 큰 주제를 가지고 그 안에 세부주제로 'HTML 의 역사</span><span style="font-size: 10pt;">' , ' HTML의 기본태그 '가 들어있으며, 그 안에 각각의 소주제를 가지고 있습니다.</span></span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><b><span style="font-size: 10pt;">2. &lt;p&gt;, &lt;pre&gt;, &lt;br&gt; 태그</span></b></span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">먼저 &lt;p&gt; 태그는 문단 태그로서 텍스트를 감싸게 되는 태그입니다.</span></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">&lt;p&gt; 이것은 문단입니다. &lt;/p&gt;</span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">&lt;pre&gt; 태그는 형식화된 텍스트를 나타내는 태그로서 여기서 형식화된 텍스트란 &lt;pre&gt; 태그 안에 감싸져 있는 띄어쓰기, 들여쓰기, 줄바꿈 등이 그대로 웹 페이지에 표시하게 됩니다.</span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">&lt;pre&gt;</span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><span style="font-size: 10pt;">나는</span><span style="font-size: 10pt;"> 누구인가</span></span></p><p style="text-align: left; margin-left: 2em;"><span style="font-size: 10pt;">여기는 어디인가?</span></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">&lt;/pre&gt;</span></p><p style="text-align: left;"><span style="font-size: 14.6667px; line-height: 22px;"><br/></span></p><p style="text-align: left;"><span style="font-size: 10pt; line-height: 22px;">&lt;br&gt; 태그는 줄바꿈 태그로서 사용됩니다.</span></p><p style="text-align: left;"><br/></p><p style="text-align: left;"><span style="font-size: 10pt;">나는 누구인가? &lt;br /&gt;</span></p><p style="text-align: left;"><span style="font-size: 10pt;">여기는 어디인가? &lt;br /&gt;</span></p><p style="text-align: left;"><br/></p>

# %% [markdown]
# ## 파이썬 웹크롤링 – 웹페이지 긁어오기
# 1. 웹문서 전체 가져오기
# 2. 타이틀 가져오기
# 3. 모든 메타 데이터의 내용 가져오기
# 4. 원하는 태그의 내용 가져오기
# 5. 모든 링크의 텍스트와 주소 가져오기

# %%
#웹문서 전체 가져오기
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")  
bsObject = BeautifulSoup(html, "html.parser") 

print(bsObject)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %%
#타이틀 가져오기
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

print(bsObject.head.title)
# Out:
# <title>NAVER</title>

# %%
#모든 메타 데이터의 내용 가져오기
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

for meta in bsObject.head.find_all('meta'):
    print(meta)
# Out:
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %%
#원하는 태그의 내용 가져오기
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

print (bsObject.head.find("meta", {"property":"og:title"}))
# Out:
# <meta content="네이버" property="og:title"/>

# %%
#모든 링크의 텍스트와 주소 가져오기
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 연합뉴스 바로가기 #news_cast
# 주제별캐스트 바로가기 #themecast
# 타임스퀘어 바로가기 #time_square
# 쇼핑캐스트 바로가기 #shp_cst
# 로그인 바로가기 #account
# NAVER Whale
#
#
# 모바일의 편리함을 PC 브라우저에서도! 새로운 웨일에서 즐기는 빠르고 스마트한 인터넷
# 다운로드
# 닫기 https://whale.naver.com/whaleevent/?=main
#  http://update.whale.naver.net/downloads/installers/WhaleSetup.exe
# 네이버 /
# 네이버를 시작페이지로 http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver
# 쥬니어네이버 http://jr.naver.com
# 해피빈 http://happybean.naver.com/main/SectionMain.nhn
# 자동완성 펼치기 javascript:;
# 한글 입력기 javascript:;
# 도움말 보기 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658
# ON선택됨 #
# OFF #
# 로그인 https://nid.naver.com/nidlogin.login
# 자세히 https://help.naver.com/support/alias/search/word/word_16.naver
# 자세히 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16659
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://conol.tistory.com/24")
bsObject = BeautifulSoup(html, "html.parser")

print (bsObject.body.find("div", {"class":"area_view"}))
# Out:
# <div class="area_view">
# ...
